# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lifeexp_gdp_df = pd.read_csv('all_data.csv')

# %%
print(lifeexp_gdp_df.head())
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
print(lifeexp_gdp_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
# None

# %%
print(lifeexp_gdp_df.Year.unique())
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015]

# %%
print(lifeexp_gdp_df.Country.unique())
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']

# %% [markdown]
# Let's take a look at life expectancy vs. GDP in the US over the years

# %%
us_lifeexp_gdp_df = lifeexp_gdp_df[lifeexp_gdp_df.Country == 'United States of America'].reset_index(drop=True)

# %%
print(us_lifeexp_gdp_df.head())
# Out:
#                     Country  Year  Life expectancy at birth (years)  \
# 0  United States of America  2000                              76.8
# 1  United States of America  2001                              76.9
# 2  United States of America  2002                              77.0
# 3  United States of America  2003                              77.2
# 4  United States of America  2004                              77.5
#
#             GDP
# 0  1.030000e+13
# 1  1.060000e+13
# 2  1.100000e+13
# 3  1.150000e+13
# 4  1.230000e+13

# %%
print(us_lifeexp_gdp_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           16 non-null     object
#  1   Year                              16 non-null     int64
#  2   Life expectancy at birth (years)  16 non-null     float64
#  3   GDP                               16 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 640.0+ bytes
# None

# %%
fig, ax1 = plt.subplots()
plt.title("United States")
color = 'tab:red'
ax1.set_xlabel('Years')
ax1.set_ylabel('GDP')
ax1.plot(us_lifeexp_gdp_df.Year, us_lifeexp_gdp_df.GDP, label='GDP', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Life Expectancy', color=color)
ax2.plot(us_lifeexp_gdp_df.Year, us_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Life Expectancy at Birth (Years)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %% [markdown]
# From the graph, we can conclude that, for the United States at least, GPD and Life Expectancy at Birth is tightly and positively correlated

# %% [markdown]
# Now let us compare the GDP growths from 2000 to 2014 for all countries 'Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe'

# %%
chile_lifeexp_gdp_df = lifeexp_gdp_df[lifeexp_gdp_df.Country == 'Chile'].reset_index(drop=True)
china_lifeexp_gdp_df = lifeexp_gdp_df[lifeexp_gdp_df.Country == 'China'].reset_index(drop=True)
ger_lifeexp_gdp_df = lifeexp_gdp_df[lifeexp_gdp_df.Country == 'Germany'].reset_index(drop=True)
mx_lifeexp_gdp_df = lifeexp_gdp_df[lifeexp_gdp_df.Country == 'Germany'].reset_index(drop=True)
zim_lifeexp_gdp_df = lifeexp_gdp_df[lifeexp_gdp_df.Country == 'Zimbabwe'].reset_index(drop=True)

# %%
print(chile_lifeexp_gdp_df.head())
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
print(np.max(lifeexp_gdp_df.GDP))
# Out:
# 18100000000000.0

# %%
ax1 = plt.subplot()
ax1.plot(us_lifeexp_gdp_df.Year, us_lifeexp_gdp_df.GDP, label='US', color='tab:blue')
ax1.set_xticks([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])
ax1.set_yticks(range(0, 18100000000000, 1000000000000))
ax1.set_xticklabels(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'], rotation=90)
ax1.set_yticklabels([str(value/1000000000000) + " Trillion" for value in range(0, 18100000000000, 1000000000000)])
ax1.set_xlabel('Years')
ax1.set_ylabel('GDP (Trillion USD)')

ax2 = plt.subplot()
ax2.plot(chile_lifeexp_gdp_df.Year, chile_lifeexp_gdp_df.GDP, label='Chile', color='tab:green')

ax3 = plt.subplot()
ax3.plot(china_lifeexp_gdp_df.Year, china_lifeexp_gdp_df.GDP, label='China', color='tab:red')

ax4 = plt.subplot()
ax4.plot(ger_lifeexp_gdp_df.Year, ger_lifeexp_gdp_df.GDP, label='Germany', color='tab:pink')

ax5 = plt.subplot()
ax5.plot(mx_lifeexp_gdp_df.Year, mx_lifeexp_gdp_df.GDP, label='Mexico', color='tab:purple')

ax6 = plt.subplot()
ax6.plot(zim_lifeexp_gdp_df.Year, zim_lifeexp_gdp_df.GDP, label='Zimbabwe', color='tab:brown')

plt.legend()

plt.show()
plt.clf()

# %% [markdown]
# Now let us compare the life expectancy growths from 2000 to 2014 for all countries 'Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe'

# %%
print(np.max(lifeexp_gdp_df['Life expectancy at birth (years)']))
# Out:
# 81.0

# %%
ax1 = plt.subplot()
ax1.plot(us_lifeexp_gdp_df.Year, us_lifeexp_gdp_df['Life expectancy at birth (years)'], label='US', color='tab:blue')
ax1.set_xticks([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])
ax1.set_yticks(range(0, 85, 5))
ax1.set_xticklabels(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'], rotation=90)
ax1.set_yticklabels([str(value) for value in range(0, 85, 5)])
ax1.set_xlabel('Years')
ax1.set_ylabel('Life Expectancy at Birth (Years)')

ax2 = plt.subplot()
ax2.plot(chile_lifeexp_gdp_df.Year, chile_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Chile', color='tab:green')

ax3 = plt.subplot()
ax3.plot(china_lifeexp_gdp_df.Year, china_lifeexp_gdp_df['Life expectancy at birth (years)'], label='China', color='tab:red')

ax4 = plt.subplot()
ax4.plot(ger_lifeexp_gdp_df.Year, ger_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Germany', color='tab:pink')

ax5 = plt.subplot()
ax5.plot(mx_lifeexp_gdp_df.Year, mx_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Mexico', color='tab:purple')

ax6 = plt.subplot()
ax6.plot(zim_lifeexp_gdp_df.Year, zim_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Zimbabwe', color='tab:brown')

plt.legend()

plt.show()
plt.clf()

# %% [markdown]
# It appears that, when comparing the GDP growth and the life-expectancy growth figures between all countries, that the expectation that GDP growth is postiively correlated with life expectancy growth holds true; let's a take a closer look at all these countries

# %%
fig, ax1 = plt.subplots()
plt.title("Zimbabwe")
color = 'tab:red'
ax1.set_xlabel('Years')
ax1.set_ylabel('GDP')
ax1.plot(zim_lifeexp_gdp_df.Year, zim_lifeexp_gdp_df.GDP, label='GDP', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Life Expectancy', color=color)
ax2.plot(zim_lifeexp_gdp_df.Year, zim_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Life Expectancy at Birth (Years)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %% [markdown]
# Per the GDP vs. Life Expectancy at Birth plot above, Zimbabwe's life expectancy continued to rise despite a dip in its economic fortunes around the GFR of 2008 and accelerated when economic growth picked back up in the years after. However, unlike most countries being analyzed here, Zimbabwe's economy and life expectancy is lower than the others as the country is not as developed.

# %%
fig, ax1 = plt.subplots()
plt.title("Chile")
color = 'tab:red'
ax1.set_xlabel('Years')
ax1.set_ylabel('GDP')
ax1.plot(chile_lifeexp_gdp_df.Year, chile_lifeexp_gdp_df.GDP, label='GDP', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Life Expectancy', color=color)
ax2.plot(chile_lifeexp_gdp_df.Year, chile_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Life Expectancy at Birth (Years)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %% [markdown]
# In Chile, gains in life expectancy outpaced economic growth for most of time between 2001 to 2014, only falling behind from 2010 to 2013.

# %%
fig, ax1 = plt.subplots()
plt.title("China")
color = 'tab:red'
ax1.set_xlabel('Years')
ax1.set_ylabel('GDP')
ax1.plot(china_lifeexp_gdp_df.Year, china_lifeexp_gdp_df.GDP, label='GDP', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Life Expectancy', color=color)
ax2.plot(china_lifeexp_gdp_df.Year, china_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Life Expectancy at Birth (Years)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %% [markdown]
# In China, it appears that life expectancy gains outpaced GDP growth through most of the years between 2000 and 2014.

# %%
fig, ax1 = plt.subplots()
plt.title("Germany")
color = 'tab:red'
ax1.set_xlabel('Years')
ax1.set_ylabel('GDP')
ax1.plot(ger_lifeexp_gdp_df.Year, ger_lifeexp_gdp_df.GDP, label='GDP', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Life Expectancy', color=color)
ax2.plot(ger_lifeexp_gdp_df.Year, ger_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Life Expectancy at Birth (Years)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %% [markdown]
# GDP growth outperformed life-expectancy gains in Germany for most of the period from 2010 to 2014 with the only exception being in 2012.

# %%
fig, ax1 = plt.subplots()
plt.title("Mexico")
color = 'tab:red'
ax1.set_xlabel('Years')
ax1.set_ylabel('GDP')
ax1.plot(mx_lifeexp_gdp_df.Year, mx_lifeexp_gdp_df.GDP, label='GDP', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Life Expectancy', color=color)
ax2.plot(mx_lifeexp_gdp_df.Year, mx_lifeexp_gdp_df['Life expectancy at birth (years)'], label='Life Expectancy at Birth (Years)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %% [markdown]
# Similar to Germany, life expectancy gains was outpaced by GDP growth for most of the period from 2000 to 2014 for Mexico

# %% [markdown]
# Now let's see if gains in life expectancy and GDP are comparable across all countries

# %%
print(lifeexp_gdp_df.head())
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
GDP_by_year = lifeexp_gdp_df.groupby('Year').GDP.sum().reset_index()

# %%
print(GDP_by_year)
# Out:
#     Year           GDP
# 0   2000  1.422950e+13
# 1   2001  1.469251e+13
# 2   2002  1.536733e+13
# 3   2003  1.646068e+13
# 4   2004  1.794988e+13
# 5   2005  1.924245e+13
# 6   2006  2.078009e+13
# 7   2007  2.271450e+13
# 8   2008  2.433591e+13
# 9   2009  2.400392e+13
# 10  2010  2.579752e+13
# 11  2011  2.826579e+13
# 12  2012  2.977249e+13
# 13  2013  3.161555e+13
# 14  2014  3.334835e+13
# 15  2015  3.395139e+13

# %%
lifeexp_by_year = lifeexp_gdp_df.groupby('Year')['Life expectancy at birth (years)'].mean().reset_index()

# %%
print(lifeexp_by_year)
# Out:
#     Year  Life expectancy at birth (years)
# 0   2000                         70.766667
# 1   2001                         70.833333
# 2   2002                         70.950000
# 3   2003                         71.033333
# 4   2004                         71.300000
# 5   2005                         71.483333
# 6   2006                         71.950000
# 7   2007                         72.300000
# 8   2008                         72.666667
# 9   2009                         73.066667
# 10  2010                         73.483333
# 11  2011                         74.200000
# 12  2012                         74.600000
# 13  2013                         74.966667
# 14  2014                         75.316667
# 15  2015                         75.716667

# %%
lifeexp_vs_GDP = GDP_by_year.merge(lifeexp_by_year)
print(lifeexp_vs_GDP)
# Out:
#     Year           GDP  Life expectancy at birth (years)
# 0   2000  1.422950e+13                         70.766667
# 1   2001  1.469251e+13                         70.833333
# 2   2002  1.536733e+13                         70.950000
# 3   2003  1.646068e+13                         71.033333
# 4   2004  1.794988e+13                         71.300000
# 5   2005  1.924245e+13                         71.483333
# 6   2006  2.078009e+13                         71.950000
# 7   2007  2.271450e+13                         72.300000
# 8   2008  2.433591e+13                         72.666667
# 9   2009  2.400392e+13                         73.066667
# 10  2010  2.579752e+13                         73.483333
# 11  2011  2.826579e+13                         74.200000
# 12  2012  2.977249e+13                         74.600000
# 13  2013  3.161555e+13                         74.966667
# 14  2014  3.334835e+13                         75.316667
# ...

# %%
fig, ax1 = plt.subplots()
plt.title("Global GDP vs. Mean Life Expectancy at Birth")
color = 'tab:red'
ax1.set_xlabel('Years')
ax1.set_ylabel('GDP')
ax1.plot(lifeexp_vs_GDP.Year, lifeexp_vs_GDP.GDP, label='GDP', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Life Expectancy', color=color)
ax2.plot(lifeexp_vs_GDP.Year, lifeexp_vs_GDP['Life expectancy at birth (years)'], label='Life Expectancy at Birth (Years)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %% [markdown]
# Globally, GDP growth outpaced Life-expectancy gains, the two trends only coming close after the GFC of 2008

# %% [markdown]
# Let's see if rate of change of GDP over 2002 to 2014 and rate of change of life expectancy is related.

# %%
lifeexp_vs_GDP['GDP ROC'] = lifeexp_vs_GDP.GDP.diff()

# %%
lifeexp_vs_GDP['Life Expectancy at Birth ROC'] = lifeexp_vs_GDP['Life expectancy at birth (years)'].diff()

# %%
fig, ax1 = plt.subplots()
plt.title("Global GDP Rate of Chanage vs. Mean Life Expectancy at Birth Rate of Change")
color = 'tab:red'
ax1.set_xlabel('Mean Years Change in Years')
ax1.set_ylabel('GDP Change in Trillions')
ax1.set_xticks([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])
ax1.set_xticklabels(["From {} to {}".format(year-1, year) for year in range(2001, 2016, 1)], rotation = 90)
ax1.plot(lifeexp_vs_GDP.Year, lifeexp_vs_GDP['GDP ROC'], label='GDP', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Life Expectancy', color=color)
ax2.plot(lifeexp_vs_GDP.Year, lifeexp_vs_GDP['Life Expectancy at Birth ROC'], label='Life Expectancy at Birth ROC', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %%
print(lifeexp_vs_GDP.head())
# Out:
#    Year           GDP  Life expectancy at birth (years)       GDP ROC  \
# 0  2000  1.422950e+13                         70.766667           NaN
# 1  2001  1.469251e+13                         70.833333  4.630124e+11
# 2  2002  1.536733e+13                         70.950000  6.748176e+11
# 3  2003  1.646068e+13                         71.033333  1.093346e+12
# 4  2004  1.794988e+13                         71.300000  1.489209e+12
#
#    Life Expectancy at Birth ROC
# 0                           NaN
# 1                      0.066667
# 2                      0.116667
# 3                      0.083333
# 4                      0.266667

# %%
lifeexp_vs_GDP['GDP pct change'] = lifeexp_vs_GDP.GDP.pct_change()*100

# %%
lifeexp_vs_GDP['Mean Life Expectancy at Birth pct Change'] = lifeexp_vs_GDP['Life expectancy at birth (years)'].pct_change()*100

# %%
print(lifeexp_vs_GDP)
# Out:
#     Year           GDP  Life expectancy at birth (years)       GDP ROC  \
# 0   2000  1.422950e+13                         70.766667           NaN
# 1   2001  1.469251e+13                         70.833333  4.630124e+11
# 2   2002  1.536733e+13                         70.950000  6.748176e+11
# 3   2003  1.646068e+13                         71.033333  1.093346e+12
# 4   2004  1.794988e+13                         71.300000  1.489209e+12
# 5   2005  1.924245e+13                         71.483333  1.292562e+12
# 6   2006  2.078009e+13                         71.950000  1.537647e+12
# 7   2007  2.271450e+13                         72.300000  1.934405e+12
# 8   2008  2.433591e+13                         72.666667  1.621416e+12
# 9   2009  2.400392e+13                         73.066667 -3.319941e+11
# 10  2010  2.579752e+13                         73.483333  1.793600e+12
# 11  2011  2.826579e+13                         74.200000  2.468271e+12
# ...

# %%
fig, ax1 = plt.subplots()
plt.title("Global GDP vs. Mean Life Expectancy at Birth % Change")
color = 'tab:red'
ax1.set_xlabel('Mean Years % Change')
ax1.set_ylabel('GDP % Change')
ax1.set_xticks([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])
ax1.set_xticklabels(["From {} to {}".format(year-1, year) for year in range(2001, 2016, 1)], rotation = 90)
ax1.set_yticks([i for i in range(-3, 11, 1)])
ax1.set_yticklabels([f'{i}%' for i in range(-3, 11, 1)])
ax1.plot(lifeexp_vs_GDP.Year, lifeexp_vs_GDP['GDP pct change'], label='GDP % Change', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()



ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Mean Life Expectancy % Change', color=color)
ax2.plot(lifeexp_vs_GDP.Year, lifeexp_vs_GDP['Mean Life Expectancy at Birth pct Change'], label='Life Expectancy at Birth % Change', color=color)
ax2.set_yticks([i/10 for i in range(1, 11, 1)])
ax2.set_yticklabels([str(i/10) + '%' for i in range(1, 11, 1)])
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %% [markdown]
# Based on the pct change in GDP and Life Expectancy, throughout the period from 2000 to 2015, the change in mean life expectancy across the globe accelerated when GDP accelerated with more rapid acceleration occuring when GDP's rate of increase accelerated, then stagnated but didn't fall when GDP contracted from 2006 to 2009, recovered its rise from 2010 with one year lag behind GDP, and continue its rapid rise until 2011, when the GDP contracted once again and the rate of incrase slowed down.

# %% [markdown]
# Now let us compare the PCT change in GDP and Life Expectancy Increase between the US and China, the two fastest growing and largest economies

# %%
print(us_lifeexp_gdp_df.head())
print(china_lifeexp_gdp_df.head())
# Out:
#                     Country  Year  Life expectancy at birth (years)  \
# 0  United States of America  2000                              76.8
# 1  United States of America  2001                              76.9
# 2  United States of America  2002                              77.0
# 3  United States of America  2003                              77.2
# 4  United States of America  2004                              77.5
#
#             GDP
# 0  1.030000e+13
# 1  1.060000e+13
# 2  1.100000e+13
# 3  1.150000e+13
# 4  1.230000e+13
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   China  2000                              71.7  1.211350e+12
# 1   China  2001                              72.2  1.339400e+12
# 2   China  2002                              72.7  1.470550e+12
# 3   China  2003                              73.1  1.660290e+12
# 4   China  2004                              73.5  1.955350e+12

# %%
us_lifeexp_gdp_df['GDP Pct Change'] = us_lifeexp_gdp_df.GDP.pct_change()*100
us_lifeexp_gdp_df['Mean Life Expectancy at Birth Pct Change'] = us_lifeexp_gdp_df['Life expectancy at birth (years)'].pct_change()*100
us_lifeexp_gdp_df.dropna(inplace=True)

# %%
print(us_lifeexp_gdp_df)
# Out:
#                      Country  Year  Life expectancy at birth (years)  \
# 1   United States of America  2001                              76.9
# 2   United States of America  2002                              77.0
# 3   United States of America  2003                              77.2
# 4   United States of America  2004                              77.5
# 5   United States of America  2005                              77.5
# 6   United States of America  2006                              77.8
# 7   United States of America  2007                              78.1
# 8   United States of America  2008                              78.2
# 9   United States of America  2009                              78.5
# 10  United States of America  2010                              78.7
# 11  United States of America  2011                              78.7
# 12  United States of America  2012                              78.8
# 13  United States of America  2013                              78.9
# ...

# %%
china_lifeexp_gdp_df['GDP Pct Change'] = china_lifeexp_gdp_df.GDP.pct_change()*100
china_lifeexp_gdp_df['Mean Life Expectancy at Birth Pct Change'] = china_lifeexp_gdp_df['Life expectancy at birth (years)'].pct_change()*100
china_lifeexp_gdp_df.dropna(inplace=True)

# %%
print(china_lifeexp_gdp_df)
# Out:
#    Country  Year  Life expectancy at birth (years)           GDP  \
# 1    China  2001                              72.2  1.339400e+12
# 2    China  2002                              72.7  1.470550e+12
# 3    China  2003                              73.1  1.660290e+12
# 4    China  2004                              73.5  1.955350e+12
# 5    China  2005                              73.9  2.285970e+12
# 6    China  2006                              74.2  2.752130e+12
# 7    China  2007                              74.4  3.552180e+12
# 8    China  2008                              74.5  4.598210e+12
# 9    China  2009                              74.9  5.109950e+12
# 10   China  2010                              75.0  6.100620e+12
# 11   China  2011                              75.2  7.572550e+12
# 12   China  2012                              75.4  8.560550e+12
# 13   China  2013                              75.6  9.607220e+12
# ...

# %%
fig, ax1 = plt.subplots()
plt.title("US GDP vs. Mean Life Expectancy at Birth % Change")
color = 'tab:red'
ax1.set_xlabel('Mean Years % Change')
ax1.set_ylabel('GDP % Change')
ax1.set_xticks([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])
ax1.set_xticklabels(["From {} to {}".format(year-1, year) for year in range(2001, 2016, 1)], rotation = 90)
ax1.set_yticks([i for i in range(-3, 11, 1)])
ax1.set_yticklabels([f'{i}%' for i in range(-3, 11, 1)])
ax1.plot(us_lifeexp_gdp_df.Year, us_lifeexp_gdp_df['GDP Pct Change'], label='GDP % Change', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend(loc=1)



ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Mean Life Expectancy % Change', color=color)
ax2.plot(us_lifeexp_gdp_df.Year, us_lifeexp_gdp_df['Mean Life Expectancy at Birth Pct Change'], label='Life Expectancy at Birth % Change', color=color)
ax2.set_yticks([i/10 for i in range(0, 5, 1)])
ax2.set_yticklabels([str(i/10) + '%' for i in range(0, 5, 1)])
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=4)
fig.tight_layout()
plt.show()

# %% [markdown]
# For the United States, which had a higher than global mean life expectancy at birth going into the year 2000, accelerating GDP growth was correlated with accelerating growth in the life expectancy at birth; inversely, the deceleration in economic growth is not necessarily associated with a deceleration in the rate of growth of life expectancy

# %%
print(np.max(china_lifeexp_gdp_df['GDP Pct Change']))
# Out:
# 29.44755051827328

# %%
fig, ax1 = plt.subplots()
plt.title("China GDP vs. Mean Life Expectancy at Birth % Change")
color = 'tab:red'
ax1.set_xlabel('Mean Years % Change')
ax1.set_ylabel('GDP % Change')
ax1.set_xticks([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])
ax1.set_xticklabels(["From {} to {}".format(year-1, year) for year in range(2001, 2016, 1)], rotation = 90)
ax1.set_yticks([i for i in range(-3, 30, 2)])
ax1.set_yticklabels([f'{i}%' for i in range(-3, 30, 2)])
ax1.plot(china_lifeexp_gdp_df.Year, china_lifeexp_gdp_df['GDP Pct Change'], label='GDP % Change', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend()



ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Mean Life Expectancy % Change', color=color)
ax2.plot(china_lifeexp_gdp_df.Year, china_lifeexp_gdp_df['Mean Life Expectancy at Birth Pct Change'], label='Life Expectancy at Birth % Change', color=color)
ax2.set_yticks([i/10 for i in range(0, 8, 1)])
ax2.set_yticklabels([str(i/10) + '%' for i in range(0, 8, 1)])
ax2.tick_params(axis='y', labelcolor=color)
plt.legend(loc=1)
fig.tight_layout()
plt.show()

# %% [markdown]
# In China, record economic acceleration from 2000 to 2008 was associated with meager and falling rate of growth in life expectancy; additionally, it appears that with a falling rate of growth of GDP, life expectancy growth accelerated and the two trens seem to be inversely related after 2008.
